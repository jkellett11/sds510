# %% [markdown]
# **4.4 Playing with Data Traces**

# %% [markdown]
# For this assignment, I am going to look at data traces within my gmail data.

# %%
#Importing Libraries
import mailbox
import csv
import pandas as pd
import numpy as np
import datetime as dt
import config
import plotly.express as px
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
#for this codeblock, I used a youtube tutorial as a reference.
#google gave me the data as an mbox file, following a tutorial I was able to read it into a csv.
writer=csv.writer(open('mail.csv','w'))
for message in mailbox.mbox("/Users/jasminekellett/Desktop/All mail Including Spam and Trash-001.mbox"):
    writer.writerow([message['to'], message['from'], message['date']])

# %%
#converting the csv to pandas for manipulation purposes.
maildf=pd.read_csv('mail.csv')

# %%
#adding a header to the dataframe as the csv only consists of the raw data
header = ['recipient', 'sender', 'timestamp']
maildf.columns=header

# %%
#including this step to hide my personal email if I post this to github!
#Note: after continued issues with troubleshooting I did run this line of code through anacondas AI tool to discover I needed to include an na=False term to avoid na errors.

maildf.loc[maildf['recipient'].str.contains(config.UNAME, case=False, na=False), 'recipient'] = 'personal_email'
maildf.loc[maildf['sender'].str.contains(config.UNAME, case=False, na=False), 'sender'] = 'personal_email'

maildf.loc[maildf['recipient'].str.contains(config.SNAME, case=False, na=False), 'recipient'] = 'school_email'
maildf.loc[maildf['recipient'].str.contains(config.SVNAME, case=False, na=False), 'recipient'] = 'school_email'

# %%
#summary of dataframe so far.
maildf.info()
#due to the size of this dataframe, I will only be examining the first 10,000 rows. I may trim that down further later.
newdf = maildf[0:10000]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43745 entries, 0 to 43744
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   recipient  43703 non-null  object
#  1   sender     43745 non-null  object
#  2   timestamp  43729 non-null  object
# dtypes: object(3)
# memory usage: 1.0+ MB

# %%
display(newdf)
# Out:
#            recipient                                             sender  \
# 0     personal_email           "My Degree Path" <news@mydegreepath.com>
# 1     personal_email  "Urban Outfitters" <urbanoutfitters@s.urbanout...
# 2     personal_email                       "IHOP" <info@email.ihop.com>
# 3     personal_email  "Urban Outfitters" <urbanoutfitters@s.urbanout...
# 4     personal_email  =?UTF-8?B?RGlzY292ZXI=?= <discover@card-e.em.d...
# ...              ...                                                ...
# 9995  personal_email              Good Dye Young <hey@gooddyeyoung.com>
# 9996  personal_email         Universal Yums <support@universalyums.com>
# 9997  personal_email                   "SHEIN" <info@news.us.shein.com>
# 9998  personal_email             My Degree Path <news@mydegreepath.com>
# 9999  personal_email                        Twitch <no-reply@twitch.tv>
#
#                                   timestamp
# 0                05 Feb 2026 02:32:36 -0000
# 1           Thu, 05 Feb 2026 17:45:34 -0600
# 2           Thu, 05 Feb 2026 11:07:26 -0600
# 3           Fri, 30 Jan 2026 17:32:15 -0600
# 4            Mon, 2 Feb 2026 19:02:02 +0000
# ...                                     ...
# 9995  Sat, 27 Sep 2025 06:01:22 +0000 (UTC)
# 9996  Sat, 27 Sep 2025 03:15:06 +0000 (UTC)
# 9997        Tue, 23 Sep 2025 05:41:55 +0200
# 9998        Thu, 25 Sep 2025 04:20:40 +0000
# 9999        Thu, 25 Sep 2025 14:49:41 +0000
#
# [10000 rows x 3 columns]

# %% [markdown]
# **Converting the Timestamp Column to Datetime**

# %%
#in order to explore the data later on we must first convert the timestamp data to datetime.
#note: format='mixed' was used as this dataset contains varied timestamp configurations. and utc='True' was included due a depreciation warning.
newdf['newtime']=pd.to_datetime(newdf['timestamp'], format='mixed', utc='True')
# Out:
# /var/folders/ks/cfqp33wd7g72hx80g1yp8ln40000gn/T/ipykernel_71560/842098103.py:3: FutureWarning:
#
# Parsing 'MST' as tzlocal (dependent on system timezone) is deprecated and will raise in a future version. Pass the 'tz' keyword or call tz_localize after construction instead
#
# /var/folders/ks/cfqp33wd7g72hx80g1yp8ln40000gn/T/ipykernel_71560/842098103.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#datetime check!
display(newdf)
newdf.dtypes
# Out:
#            recipient                                             sender  \
# 0     personal_email           "My Degree Path" <news@mydegreepath.com>
# 1     personal_email  "Urban Outfitters" <urbanoutfitters@s.urbanout...
# 2     personal_email                       "IHOP" <info@email.ihop.com>
# 3     personal_email  "Urban Outfitters" <urbanoutfitters@s.urbanout...
# 4     personal_email  =?UTF-8?B?RGlzY292ZXI=?= <discover@card-e.em.d...
# ...              ...                                                ...
# 9995  personal_email              Good Dye Young <hey@gooddyeyoung.com>
# 9996  personal_email         Universal Yums <support@universalyums.com>
# 9997  personal_email                   "SHEIN" <info@news.us.shein.com>
# 9998  personal_email             My Degree Path <news@mydegreepath.com>
# 9999  personal_email                        Twitch <no-reply@twitch.tv>
#
#                                   timestamp                   newtime
# 0                05 Feb 2026 02:32:36 -0000 2026-02-05 02:32:36+00:00
# 1           Thu, 05 Feb 2026 17:45:34 -0600 2026-02-05 23:45:34+00:00
# 2           Thu, 05 Feb 2026 11:07:26 -0600 2026-02-05 17:07:26+00:00
# 3           Fri, 30 Jan 2026 17:32:15 -0600 2026-01-30 23:32:15+00:00
# 4            Mon, 2 Feb 2026 19:02:02 +0000 2026-02-02 19:02:02+00:00
# ...                                     ...                       ...
# 9995  Sat, 27 Sep 2025 06:01:22 +0000 (UTC) 2025-09-27 06:01:22+00:00
# 9996  Sat, 27 Sep 2025 03:15:06 +0000 (UTC) 2025-09-27 03:15:06+00:00
# 9997        Tue, 23 Sep 2025 05:41:55 +0200 2025-09-23 03:41:55+00:00
# 9998        Thu, 25 Sep 2025 04:20:40 +0000 2025-09-25 04:20:40+00:00
# 9999        Thu, 25 Sep 2025 14:49:41 +0000 2025-09-25 14:49:41+00:00
#
# [10000 rows x 4 columns]
# recipient                 object
# sender                    object
# timestamp                 object
# newtime      datetime64[ns, UTC]
# dtype: object

# %%
#sorting the df in descending order for easier readbility
newdf=newdf.sort_values(by='newtime', ascending=False)
display(newdf)
# Out:
#            recipient                                             sender  \
# 264   personal_email              Google <no-reply@accounts.google.com>
# 265   personal_email              Google <no-reply@accounts.google.com>
# 480   personal_email                       Google <no-reply@google.com>
# 1485  personal_email              Google <no-reply@accounts.google.com>
# 19    personal_email          "Instagram" <no-reply@mail.instagram.com>
# ...              ...                                                ...
# 9973  personal_email                          Rowan <info@heyrowan.com>
# 9924  personal_email  =?UTF-8?B?TGVuc0NyYWZ0ZXJz?= <news@e.lenscraft...
# 9985  personal_email            DICK'S Sporting Goods  <DSG@e.dcsg.com>
# 9997  personal_email                   "SHEIN" <info@news.us.shein.com>
# 9976  personal_email      Dutch Bros Coffee <rewards@app.dutchbros.com>
#
#                                   timestamp                   newtime
# 264           Fri, 06 Feb 2026 07:19:53 GMT 2026-02-06 07:19:53+00:00
# 265           Fri, 06 Feb 2026 07:11:00 GMT 2026-02-06 07:11:00+00:00
# 480         Thu, 05 Feb 2026 23:07:38 -0800 2026-02-06 07:07:38+00:00
# 1485          Fri, 06 Feb 2026 07:06:34 GMT 2026-02-06 07:06:34+00:00
# 19           Thu, 5 Feb 2026 23:00:10 -0800 2026-02-06 07:00:10+00:00
# ...                                     ...                       ...
# 9973  Tue, 23 Sep 2025 13:02:18 +0000 (UTC) 2025-09-23 13:02:18+00:00
# 9924        Tue, 23 Sep 2025 11:01:21 +0000 2025-09-23 11:01:21+00:00
# 9985        Tue, 23 Sep 2025 07:21:03 +0000 2025-09-23 07:21:03+00:00
# 9997        Tue, 23 Sep 2025 05:41:55 +0200 2025-09-23 03:41:55+00:00
# 9976  Tue, 23 Sep 2025 03:12:58 +0000 (UTC) 2025-09-23 03:12:58+00:00
#
# [10000 rows x 4 columns]

# %%
#due to the size of the df, I will focus on the last two weeks of data. I filtered the email dataset to the last two weeks: 1-19-2026 to 2-5-2026.
filterdf=newdf[newdf['newtime']>'2026-1-22'].reset_index()
display(filterdf)
# Out:
#       index       recipient  \
# 0       264  personal_email
# 1       265  personal_email
# 2       480  personal_email
# 3      1485  personal_email
# 4        19  personal_email
# ...     ...             ...
# 1074    915  personal_email
# 1075    682  personal_email
# 1076   1037  personal_email
# 1077   1506  personal_email
# 1078    766  personal_email
#
#                                                  sender  \
# 0                 Google <no-reply@accounts.google.com>
# 1                 Google <no-reply@accounts.google.com>
# 2                          Google <no-reply@google.com>
# 3                 Google <no-reply@accounts.google.com>
# 4             "Instagram" <no-reply@mail.instagram.com>
# ...                                                 ...
# 1074                  "Ulta Beauty" <U-Mail@e.ulta.com>
# 1075  "Steve Madden" <stevemadden@email.stevemadden....
# 1076  =?utf-8?b?4py/c2hpdCB5b3Ugc2hvdWxkIGNhcmUgYWJv...
# 1077              "HelloFresh" <hello@g.hellofresh.com>
# 1078                        AKIRA <hello@shopakira.com>
#
#                                   timestamp                   newtime
# 0             Fri, 06 Feb 2026 07:19:53 GMT 2026-02-06 07:19:53+00:00
# 1             Fri, 06 Feb 2026 07:11:00 GMT 2026-02-06 07:11:00+00:00
# 2           Thu, 05 Feb 2026 23:07:38 -0800 2026-02-06 07:07:38+00:00
# 3             Fri, 06 Feb 2026 07:06:34 GMT 2026-02-06 07:06:34+00:00
# 4            Thu, 5 Feb 2026 23:00:10 -0800 2026-02-06 07:00:10+00:00
# ...                                     ...                       ...
# 1074        Wed, 21 Jan 2026 19:17:17 -0600 2026-01-22 01:17:17+00:00
# 1075        Thu, 22 Jan 2026 01:14:48 +0000 2026-01-22 01:14:48+00:00
# 1076        Thu, 22 Jan 2026 00:39:51 +0000 2026-01-22 00:39:51+00:00
# 1077        Wed, 21 Jan 2026 18:12:51 -0600 2026-01-22 00:12:51+00:00
# 1078  Thu, 22 Jan 2026 00:12:07 +0000 (UTC) 2026-01-22 00:12:07+00:00
#
# [1079 rows x 5 columns]

# %%
sendercounts=filterdf['sender'].unique()
display(sendercounts)
# Out:
# array(['Google <no-reply@accounts.google.com>',
#        'Google <no-reply@google.com>',
#        '"Instagram" <no-reply@mail.instagram.com>',
#        '"Instagram" <security@mail.instagram.com>',
#        '"JENNIE" <JENNIE@emails.sonymusicfans.com>',
#        'Reddit <noreply@redditmail.com>',
#        'Good Dye Young <hey@gooddyeyoung.com>',
#        '"NORDSTROM RACK" <nordstromrack@eml.nordstromrack.com>',
#        '"My Degree Path" <news@mydegreepath.com>',
#        'SHEIN <shein@news.emailmarket.shein.com>',
#        '"Mark Kelly" <feedback@e.democrats.org>',
#        '"Target" <targetnews@em.target.com>',
#        'YUNGBLUD Official Store <Yungblud@us.umusic-online.com>',
#        '"Ulta Beauty" <U-Mail@e.ulta.com>',
#        'Tumblr <no-reply@tumblr.com>',
#        '"Redbubble" <heythere@m.redbubble.com>',
#        'AKIRA <hello@shopakira.com>', 'Disturbia <info@disturbia.us>',
#        '"Urban Outfitters" <urbanoutfitters@s.urbanoutfitters.com>',
#        '=?iso-8859-1?q?A=E9ropostale?= <aeropostale@offers.aeropostale.com>',
#        '"SHEIN" <shein@market-us.shein.com>',
#        '"Hot Topic" <noreply@s.hottopic.com>',
#        'Creepy Nuts via Bandsintown <notifications@ppt.bandsintown.com>',
#        '"Phoenix Children\'s Foundation & Concours in the Hills" <concours_in_the_hills@phoenixchildrens.com>',
#        'Patricia Nash <info@email.patricianashdesigns.com>',
#        'Edible Arrangements <sweetdeals@p.ediblearrangements.com>',
#        'Universal Music Group <info@us.umusic-online.com>',
#        '"Democrats.org" <feedback@e.democrats.org>',
#        '"Sam\'s Club" <Samsclub@em.samsclub.com>',
#        '"Kamala Harris" <contact@e.kamalaharris.com>',
#        'Shanti Sound <info@shantisoundaz.com>',
#        '"Rituel de Fille" <contact@ritueldefille.com>',
#        'Haus Labs <no-reply@hauslabs.com>',
#        '"Journeys" <journeys@em.journeys.com>',
#        'SHEIN <shein@news.edmmarket.shein.com>',
#        '"Flip the Senate" <information@democrats.senatemajority.com>',
#        '"Society6" <noreply@society6.com>',
#        '"Little Caesars" <littlecaesars@pizzapizza.littlecaesars.com>',
#        'Sallie Mae <smartoption@soslprospect.salliemae.com>',
#        'Zoom <no-reply@zoom.us>', '"Critical Role" <doty@critrole.com>',
#        '"See\'s Candies" <sees@e.sees.com>',
#        '"BoxLunch" <noreply@s.boxlunch.com>',
#        'Firehouse Subs <411@email.firehousesubschatter.com>',
#        '"Dr. Martens" <hello@drmartens.com>',
#        '"PlayStation" <email@email.playstation.com>',
#        'The Washington Post <email@washingtonpost.com>',
#        'POP MART <support@market.popmart.com>',
#        'Chick-fil-A <one@email.chick-fil-a.com>',
#        '"Business Insider" <subscriptions@email.businessinsider.com>',
#        '"IHOP" <info@email.ihop.com>', 'PopSockets <cs@popsockets.com>',
#        'Warby Parker <sayhello@mail2.warbyparker.com>',
#        '"r.e.m. beauty" <hi@email.rembeauty.com>',
#        '"The Democrats" <feedback@e.democrats.org>',
#        '"Murphy Door, Inc." <sales@murphydoor.com>',
#        '"Sonic" <noreply@email.sonicdrivein.com>',
#        '"Old Navy" <oldnavy@email.oldnavy.com>',
#        '"The Washington Post" <info@e.mail.washingtonpost.com>',
#        '"SKIMS" <no-reply@emails.skims.com>',
#        '"JCPenney" <JCPenney@email.jcpenney.com>',
#        '=?UTF-8?B?TGVuc0NyYWZ0ZXJz?= <news@e.lenscrafters.com>',
#        '"Disney Store" <disneystore@em.disneystore.com>',
#        'iHeartRadio <iheartradio@listen.iheart.com>',
#        'BARK <hello@bark.co>', 'Fandango <fandango@movies.fandango.com>',
#        '"Dose" <weactuallycare@dosedaily.co>',
#        'Rowan <info@heyrowan.com>',
#        'W Concept <hello@email.wconcept.com>',
#        'Fenty Beauty <noreply@fentybeauty.com>',
#        '=?utf-8?b?SE9LQcKu?= <info@emails.hoka.com>',
#        "DICK'S Sporting Goods  <DSG@e.dcsg.com>",
#        'Spotify <no-reply@spotify.com>',
#        'Cecile Babich Morrow <cecile.babich.morrow@users.smore.com>',
#        '"Steve Madden" <stevemadden@email.stevemadden.com>',
#        'yamaoctavia on TikTok <notification@service.tiktok.com>',
#        'Uber <uber@uber.com>', '"ASU Alumni Chapters" <alumni@s.asu.edu>',
#        'Bandsintown <notifications@updates.bandsintown.com>',
#        '"DoorDash" <no-reply@messages.doordash.com>',
#        '"=?UTF-8?B?T0xJVkUgWU9VTkc=?=" <shop@oliveyoung.com>',
#        'Regalrose <care@regalrose.co.uk>',
#        '"NORDSTROM RACK FLASH" <nordstromrack@eml.nordstromrack.com>',
#        'BURGA <hello@burga.com>',
#        'Ozzy Osbourne Store <marketing@globalmerchservices.com>',
#        'Zia Records <info-ziarecords.com@shared1.ccsend.com>',
#        'Salad and Go <info@saladandgo.com>',
#        'JanSport <info@mail.jansport.com>',
#        'tiLLie <notifications@ppt.bandsintown.com>',
#        '=?utf-8?b?4py/c2hpdCB5b3Ugc2hvdWxkIGNhcmUgYWJvdXTinL8=?=\r\n <shityoushouldcareabout@substack.com>',
#        'Stanley 1913 <stanley@stanley1913.com>',
#        '"Senator Chris Murphy" <feedback@e.democrats.org>',
#        'Insight Editions <hello@insighteditions.com>',
#        '"MyPanera" <panera@m1.panerabread.com>',
#        '"New Balance" <newbalance@email.newbalance.com>',
#        'BARK Corporate <hello@bark.co>',
#        'Rakuten Viki <no-reply@marketing.viki.com>',
#        'Princess Polly <hi@princesspolly.com>',
#        'Veeps <no-reply@veeps.com>', 'Substack <no-reply@substack.com>',
#        '"Steve Schnall" <foundation@phoenixchildrens.com>',
#        '"ASU Alumni" <alumni@s.asu.edu>',
#        '=?utf-8?q?C=C3=A9cred?= <support@cecred.com>',
#        '=?UTF-8?B?U3luY2hyb255IGZvciB5b3VyIEpDUEVOTkVZ?=\r\n <customer.service@mail.synchronybank.com>',
#        '"Netflix.shop" <info@netflix.shop>',
#        'The Maine - via Bandsintown <notifications@ppt.bandsintown.com>',
#        'JCPenney <jcpenney@emails.jcpenney.com>',
#        'Popeyes <offers@m.popeyes.com>',
#        'Larkin Poe - via Bandsintown <notifications@ppt.bandsintown.com>',
#        'Girls Crew <info@shopgirlscrew.com>',
#        'Real Python <info@realpython.com>',
#        'UNiDAYS <hello@info.myunidays.com>',
#        'Sephora <shop@s.sephora.com>',
#        '"Urgent Action Alert (via DCCC)" <dccc@ak.dccc.org>',
#        '"Shake Shack" <hello@e.shakeshack.com>',
#        '"The Democratic Party" <feedback@e.democrats.org>',
#        '"Panera Bread" <panera@m1.panerabread.com>',
#        "DICK'S | Clearance  <DSG@e.dcsg.com>",
#        'Ellise - via Bandsintown <notifications@ppt.bandsintown.com>',
#        'LinkedIn <updates-noreply@linkedin.com>',
#        '"Sherrod Brown" <feedback@e.democrats.org>',
#        'JOHNNYSWIM <johnnyswim@openstageit.com>',
#        '"Ulta Beauty Rewards" <U-Mail@e.ulta.com>',
#        '"Phoenix Children\'s Foundation" <foundation@phoenixchildrens.com>',
#        'Tower 28 Beauty <hey@tower28beauty.com>',
#        'Liquid Death <info@liquiddeath.com>',
#        '"Marc Elias" <information@democrats.senatemajority.com>',
#        '"Dillards" <Dillards@email.mktgdillards.com>',
#        '=?UTF-8?B?RGlzY292ZXI=?= <discover@card-e.em.discover.com>',
#        '"McDonald\'s" <McDonalds@m.mcdonalds.com>',
#        'Panda Express <pandaexpress@email.pandaexpress.com>',
#        '"Denny\'s Rewards" <dennys-rewards@hello.dennys.com>',
#        'Blunt Cases <admin@bluntcases.com>',
#        'Philip DeFranco <philip@beautifulbastard.com>',
#        'W CONCEPT <hello@email.wconcept.com>',
#        'Universal Yums <support@universalyums.com>',
#        '=?utf-8?B?4q2Q?= Co-Star <weekly@costarastrology.com>',
#        'DoorDash Order <no-reply@doordash.com>',
#        'DoorDash <no-reply@doordash.com>',
#        '"Crocs" <email@crocs-email.com>',
#        '=?UTF-8?B?Q1ZTIFBob3Rv?= <photo@your.cvs.com>',
#        '"Ohio Alert" <information@democrats.senatemajority.com>',
#        'The Pretty Cult <Info@theprettycult.com>',
#        '"Dr. Daniel Velez @ Phoenix Children\'s" <foundation@phoenixchildrens.com>',
#        '"Team DNC" <feedback@e.democrats.org>',
#        'Red Robin <email@loyalty.redrobin.com>',
#        'Synchrony for your JCPenney Credit Card <customer.service@servicing.synchrony.com>',
#        'Genne at SkinSort <hello@skinsort.com>',
#        '"Vans" <reply@e.vans.com>',
#        '"Dutch Bros Coffee" <goodvibes@members2.dutchbros.com>',
#        '"DNC HQ" <feedback@e.democrats.org>',
#        'SaladAndGo@saladandgoemail.smg.com',
#        'Dose <weactuallycare@dosedaily.co>',
#        'Salad and Go <noreply@olo.saladandgo.com>',
#        'Olo <noreply@olo.saladandgo.com>',
#        'Hank and John <werehere@mail.beehiiv.com>',
#        'Busuu <teams@announce.busuu.com>',
#        '"Dunkin\' Rewards" <dunkinrewards@emailinfo.dunkinrewards.com>',
#        'The Substack Post <post+the-weekender@substack.com>',
#        'LinkedIn <messages-noreply@linkedin.com>',
#        '"Official Democratic Headquarters" <feedback@e.democrats.org>',
#        'Martin from Memrise <hello@mail.memrise.com>',
#        'Eventim USA <seetickets@newsletter.eventim.com>',
#        'Pierce the Veil - via Bandsintown <notifications@ppt.bandsintown.com>',
#        'Uber Eats <uber@uber.com>', '"Adobe Express" <mail@e.adobe.com>',
#        'Kesha <animals@keshaofficial.com>',
#        '"2X Match Alert" <information@democrats.senatemajority.com>',
#        '"Maya, Donor Relations Team" <feedback@e.democrats.org>',
#        'Apple <News@InsideApple.Apple.com>',
#        '"First Watch" <avotoast@goodmorning.firstwatch.com>',
#        'Against The Current - via Bandsintown\r\n\t<notifications@ppt.bandsintown.com>',
#        '"Sam\'s Club" <transaction@info.samsclub.com>',
#        'SOFIA ISELLA - via Bandsintown <notifications@ppt.bandsintown.com>',
#        'Teddy Swims - via Bandsintown <notifications@ppt.bandsintown.com>',
#        'Google Calendar <calendar-notification@google.com>',
#        'tiLLie - via Bandsintown <notifications@ppt.bandsintown.com>',
#        '"2X MATCH ALERT" <information@democrats.senatemajority.com>',
#        'Breaking Benjamin - via Bandsintown <notifications@ppt.bandsintown.com>',
#        '"Amy Klobuchar" <contact@e.kamalaharris.com>',
#        'JCPenney Credit Services  <cardholder@e.synchronyfinancial.com>',
#        'Hayley Williams <newsletter@mail.hayleywilliams.net>',
#        '"James Carville" <information@democrats.senatemajority.com>',
#        '"Amy Klobuchar" <feedback@e.democrats.org>',
#        "googly eyes from goo goo o' clock <googlyeyes@substack.com>",
#        'Dutch Bros Coffee <member@rewards.dutchbros.com>',
#        '"Alaska Update @ Flip the Senate" <information@democrats.senatemajority.com>',
#        'Nasty Gal <email@e.nastygal.com>',
#        '=?UTF-8?B?U3luY2hyb255IGZvciB5b3VyIEpDUGVubmV5IENyZWRpdCBDYQ==?=\r\n\t=?UTF-8?B?cmQ=?=\r\n <customer.service@mail.synchronybank.com>',
#        "DICK'S | Flash Sale  <DSG@e.dcsg.com>",
#        '"Ken Martin" <feedback@e.democrats.org>',
#        'Canva Create HQ <canvacreate@engage.canva.com>',
#        'Dan at Real Python <info@realpython.com>',
#        'Apple <no_reply@email.apple.com>',
#        '"Little Caesars Challenges" <challenges@pizzapizza.littlecaesars.com>',
#        'Uber Eats <ubereats@uber.com>',
#        'SYML - via Bandsintown <notifications@ppt.bandsintown.com>',
#        'Warframe <no-reply@warframe.com>',
#        'Jill Atwood <Jill.Atwood@asu.edu>',
#        'Josephine Kellett <cjjkellett@gmail.com>',
#        '"Dan Freeman (via Democrats.org)" <feedback@e.democrats.org>',
#        '"Advocacy at ASU Enterprise Partners" <advocacy@s.asuep.org>',
#        'The Substack Post <post+news-and-views@substack.com>',
#        '=?utf-8?B?TUFJTkUgQUxFUlQg4oC877iP?=\r\n\t <information@democrats.senatemajority.com>',
#        'Backstreet Boys Store <marketing@globalmerchservices.com>',
#        'Canva <marketing@engage.canva.com>',
#        '"Lewis Capaldi" <no_reply@uk-umg.com>',
#        '"=?utf-8?Q?SHOP=20BEYONC=C3=89?=" <no-reply@beyonce.com>',
#        '"Uber" <noreply@uber.com>',
#        'Lyft Receipts <no-reply@lyftmail.com>',
#        '"Nintendo" <nintendo-noreply@nintendo.net>',
#        '"The Democratic National Committee" <feedback@e.democrats.org>',
#        '"HelloFresh" <hello@g.hellofresh.com>',
#        '"Phoenix Convention Center & Venues" <info@mail-2.hive.co>',
#        '"Poppy" <hello@impoppy.com>',
#        '"Team Taylor and Phoenix Children\'s Foundation" <foundation@phoenixchildrens.com>',
#        'Veeps Shop <shop@veeps.com>',
#        'Lyft <no-reply@marketing.lyftmail.com>',
#        'Backstreet Boys - via Bandsintown <notifications@ppt.bandsintown.com>',
#        '"Arizona Financial Theatre" <arizonafinancialtheatre@eml.livenation.com>',
#        '"ASU Reach Institute" <ASUREACH@reply.asu.edu>',
#        'FedEx Delivery Manager <TrackingUpdates@fedex.com>',
#        'Insight Editions <noreply@insighteditions.com>',
#        '"Olive Young" <hello@mail.oliveyoung.com>',
#        '"ASU Alumni Partners" <alumnipartners@s.asu.edu>',
#        '"Jill Biden" <feedback@e.democrats.org>'], dtype=object)

# %% [markdown]
# Categorizing the emails

# %%
#ran into multiple errors defining a function and using np.where. Instead used .loc method with corresponding documentation worked best!
#since the majority of my emails are shopping related, I am assigning them all to that category then going in and filtering them out correct.
#I would have used np.where but there were too many categories present.
filterdf['email category'] = 'Shopping'

#filtering and recategorizing out key senders!
filterdf.loc[filterdf['sender'].str.contains('bands|spotify|sony|music|records|iheart|stageit|livenation'), 'email category'] = 'Music Updates'

filterdf.loc[filterdf['sender'].str.contains('google'), 'email category'] = 'Google Updates'

filterdf.loc[filterdf['sender'].str.contains('linkedin'), 'email category'] = 'Career'

filterdf.loc[filterdf['sender'].str.contains('fandango|netflix|hulu'), 'email category'] = 'Subscriptions'

filterdf.loc[filterdf['sender'].str.contains('insta|x|tiktok|reddit|substack|stanmail|tumblr'), 'email category'] = 'Social Media'

filterdf.loc[filterdf['sender'].str.contains('nytimes|washingtonpost|phoenixchildrens|shanti'), 'email category'] = 'News'

filterdf.loc[filterdf['sender'].str.contains('salliemae|asu|degreepath|studentaid|maricopa|airlearn'), 'email category'] = 'Education'

filterdf.loc[filterdf['sender'].str.contains('demo|dccc|kamala'), 'email category'] = 'Other'

filterdf.loc[filterdf['sender'].str.contains('sonic|chick-fil-a|panera|firehouse|caesars|ihop|doordash|uber|saladandgo|popeyes'), 'email category'] = 'Food'

filterdf.loc[filterdf['sender'].str.contains('nintendo|playstation|twitch|critrole|warframe'), 'email category'] = 'Gaming'

# %%
display(filterdf)
# Out:
#       index       recipient  \
# 0       264  personal_email
# 1       265  personal_email
# 2       480  personal_email
# 3      1485  personal_email
# 4        19  personal_email
# ...     ...             ...
# 1074    915  personal_email
# 1075    682  personal_email
# 1076   1037  personal_email
# 1077   1506  personal_email
# 1078    766  personal_email
#
#                                                  sender  \
# 0                 Google <no-reply@accounts.google.com>
# 1                 Google <no-reply@accounts.google.com>
# 2                          Google <no-reply@google.com>
# 3                 Google <no-reply@accounts.google.com>
# 4             "Instagram" <no-reply@mail.instagram.com>
# ...                                                 ...
# 1074                  "Ulta Beauty" <U-Mail@e.ulta.com>
# 1075  "Steve Madden" <stevemadden@email.stevemadden....
# 1076  =?utf-8?b?4py/c2hpdCB5b3Ugc2hvdWxkIGNhcmUgYWJv...
# 1077              "HelloFresh" <hello@g.hellofresh.com>
# 1078                        AKIRA <hello@shopakira.com>
#
#                                   timestamp                   newtime  \
# 0             Fri, 06 Feb 2026 07:19:53 GMT 2026-02-06 07:19:53+00:00
# 1             Fri, 06 Feb 2026 07:11:00 GMT 2026-02-06 07:11:00+00:00
# 2           Thu, 05 Feb 2026 23:07:38 -0800 2026-02-06 07:07:38+00:00
# 3             Fri, 06 Feb 2026 07:06:34 GMT 2026-02-06 07:06:34+00:00
# 4            Thu, 5 Feb 2026 23:00:10 -0800 2026-02-06 07:00:10+00:00
# ...                                     ...                       ...
# 1074        Wed, 21 Jan 2026 19:17:17 -0600 2026-01-22 01:17:17+00:00
# 1075        Thu, 22 Jan 2026 01:14:48 +0000 2026-01-22 01:14:48+00:00
# 1076        Thu, 22 Jan 2026 00:39:51 +0000 2026-01-22 00:39:51+00:00
# 1077        Wed, 21 Jan 2026 18:12:51 -0600 2026-01-22 00:12:51+00:00
# 1078  Thu, 22 Jan 2026 00:12:07 +0000 (UTC) 2026-01-22 00:12:07+00:00
#
#       email category
# 0     Google Updates
# 1     Google Updates
# 2     Google Updates
# 3     Google Updates
# 4       Social Media
# ...              ...
# 1074        Shopping
# 1075        Shopping
# 1076    Social Media
# 1077        Shopping
# 1078        Shopping
#
# [1079 rows x 6 columns]

# %%
#filling the single na email, with my email that was lost along the way
filterdf['recipient'].value_counts()
filterdf.fillna({'recipient':'personal_email'}, inplace=True)
# Out:
# recipient
# personal_email    1079
# Name: count, dtype: int64

# %%
filterdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1079 entries, 0 to 1078
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   index           1079 non-null   int64
#  1   recipient       1079 non-null   object
#  2   sender          1079 non-null   object
#  3   timestamp       1079 non-null   object
#  4   newtime         1079 non-null   datetime64[ns, UTC]
#  5   email category  1079 non-null   object
# dtypes: datetime64[ns, UTC](1), int64(1), object(4)
# memory usage: 50.7+ KB

# %%
categorypercent = round(filterdf['email category'].value_counts(normalize=True)*100,2)
display(categorypercent)
# Out:
# email category
# Shopping          66.08
# Social Media       7.88
# Food               6.86
# News               4.82
# Other              4.54
# Music Updates      4.08
# Education          2.69
# Gaming             1.39
# Subscriptions      0.83
# Google Updates     0.56
# Career             0.28
# Name: proportion, dtype: float64

# %%
#plot of the number of emails seen across these categories from the last two weeks.
fig = px.histogram(filterdf, x='email category', color='email category', title='Number of Emails Per Category')
fig.show()

# %%
#plot of the number of emails seen across these categories from the last two weeks.
categorypercent.plot(kind='pie', autopct='%1.1f%%')
plt.show()

# %%
filterdf['month'] = filterdf['newtime'].dt.strftime('%m')
filterdf['monthday'] = filterdf['newtime'].dt.strftime('%m-%d')
display(filterdf)
# Out:
#       index       recipient  \
# 0       264  personal_email
# 1       265  personal_email
# 2       480  personal_email
# 3      1485  personal_email
# 4        19  personal_email
# ...     ...             ...
# 1074    915  personal_email
# 1075    682  personal_email
# 1076   1037  personal_email
# 1077   1506  personal_email
# 1078    766  personal_email
#
#                                                  sender  \
# 0                 Google <no-reply@accounts.google.com>
# 1                 Google <no-reply@accounts.google.com>
# 2                          Google <no-reply@google.com>
# 3                 Google <no-reply@accounts.google.com>
# 4             "Instagram" <no-reply@mail.instagram.com>
# ...                                                 ...
# 1074                  "Ulta Beauty" <U-Mail@e.ulta.com>
# 1075  "Steve Madden" <stevemadden@email.stevemadden....
# 1076  =?utf-8?b?4py/c2hpdCB5b3Ugc2hvdWxkIGNhcmUgYWJv...
# 1077              "HelloFresh" <hello@g.hellofresh.com>
# 1078                        AKIRA <hello@shopakira.com>
#
#                                   timestamp                   newtime  \
# 0             Fri, 06 Feb 2026 07:19:53 GMT 2026-02-06 07:19:53+00:00
# 1             Fri, 06 Feb 2026 07:11:00 GMT 2026-02-06 07:11:00+00:00
# 2           Thu, 05 Feb 2026 23:07:38 -0800 2026-02-06 07:07:38+00:00
# 3             Fri, 06 Feb 2026 07:06:34 GMT 2026-02-06 07:06:34+00:00
# 4            Thu, 5 Feb 2026 23:00:10 -0800 2026-02-06 07:00:10+00:00
# ...                                     ...                       ...
# 1074        Wed, 21 Jan 2026 19:17:17 -0600 2026-01-22 01:17:17+00:00
# 1075        Thu, 22 Jan 2026 01:14:48 +0000 2026-01-22 01:14:48+00:00
# 1076        Thu, 22 Jan 2026 00:39:51 +0000 2026-01-22 00:39:51+00:00
# 1077        Wed, 21 Jan 2026 18:12:51 -0600 2026-01-22 00:12:51+00:00
# 1078  Thu, 22 Jan 2026 00:12:07 +0000 (UTC) 2026-01-22 00:12:07+00:00
#
#       email category month monthday
# 0     Google Updates    02    02-06
# 1     Google Updates    02    02-06
# 2     Google Updates    02    02-06
# 3     Google Updates    02    02-06
# 4       Social Media    02    02-06
# ...              ...   ...      ...
# 1074        Shopping    01    01-22
# 1075        Shopping    01    01-22
# 1076    Social Media    01    01-22
# 1077        Shopping    01    01-22
# 1078        Shopping    01    01-22
#
# [1079 rows x 8 columns]

# %%
#
fig = px.line(filterdf, x='month', color='email category')
fig.show()
